# %%
# %matplotlib inline
import matplotlib.pyplot as plt

plt.plot([1,2,3,4,5,6],[5,6,7,4,3,2],'*')

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = [1,2,3]
y = [5,7,4]

plt.plot(x,y)
plt.xlabel('x-Einheit')
plt.ylabel('y-Einheit')
plt.title('Erster Plot')
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = [1,2,3]
y = [5,7,4]

x2 = [1,2,3]
y2 = [10,14,12]

plt.plot(x,y, label='Graph 1')
plt.plot(x2,y2, label='Graph 2')

plt.xlabel('x-Einheit')
plt.ylabel('y-Einheit')
plt.title('Erster Plot')
plt.legend()
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = [1,3,5]
y = [5,7,4]

x2 = [2,4,6]
y2 = [10,14,12]

plt.bar(x,y, label='Graph 1', color ='r')
plt.bar(x2,y2, label='Graph 2', color = 'b')

plt.xlabel('x-Einheit')
plt.ylabel('y-Einheit')
plt.title('Bar-Plot')
plt.legend()
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

x = [1,2,3,4,5,6,7,8]
y = [2,3,6,4,9,3,6,8]

plt.scatter(x,y, label='stars', color='k', marker='*', s=100)

plt.xlabel('x')
plt.ylabel('y')
plt.title('Scatter Plot')
plt.legend()
plt.show()

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

days = [1,2,3,4,5]

sleeping = [7,8,6,11,7]
eating = [2,3,4,3,2]
working = [7,8,7,2,2]
playing = [8,5,7,8,13]

plt.stackplot(days, sleeping, eating, working,playing, colors=['m','c','r','k'])


plt.xlabel('x')
plt.ylabel('y')
plt.title('Stack Plots')
plt.legend()
plt.show()

# %%
# %matplotlib inline
import random
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')
fig = plt.figure(figsize=(16, 12))



def create_plots():
    xs = []
    ys = []
    
    for i in range(10):
        xs.append(i)
        ys.append(random.randrange(10))
    return xs,ys

ax1 = fig.add_subplot(221)
ax2 = fig.add_subplot(222)
ax3 = fig.add_subplot(212)

x,y = create_plots()
ax1.plot(x,y)

x,y = create_plots()
ax2.plot(x,y)

x,y = create_plots()
ax3.plot(x,y)

plt.show()

# %%
# %matplotlib inline
import random
import matplotlib.pyplot as plt
from matplotlib import style
style.use('fivethirtyeight')
fig = plt.figure(figsize=(16, 12))



def create_plots():
    xs = []
    ys = []
    
    for i in range(10):
        xs.append(i)
        ys.append(random.randrange(10))
    return xs,ys


ax1 = plt.subplot2grid((6,1),(0,0), rowspan=2, colspan=1)
ax2 = plt.subplot2grid((6,1),(2,0), rowspan=3, colspan=1)
ax3 = plt.subplot2grid((6,1),(5,0), rowspan=1, colspan=1)

x,y = create_plots()
ax1.plot(x,y)

x,y = create_plots()
ax2.plot(x,y)

x,y = create_plots()
ax3.plot(x,y)

plt.show()

# %%
# %matplotlib inline
import random
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import style

style.use('grayscale')
v0= 5
g = 9.81

def f(t):
    return v0*t-1.0/2*g*t**2

fig = plt.figure(figsize=(12, 8))

X = np.linspace(0, 1.2, 50)        # 50 Punkte zwischen 0 und 3
Y = np.zeros(len(X))             # Array mit gleicher Groesse
for i in xrange(len(X)):
    Y[i] = f(X[i])            # Funktionswerte berechnen

plt.plot(X,Y)
plt.show()

# %%
# %matplotlib inline
import random
import numpy as np
import matplotlib.pyplot as plt

fig = plt.figure(figsize=(12, 8))

def f(t):
      return t**2*exp(-t**2)

t = np.linspace(0, 3, 51)        # 51 Punkte zwischen 0 und 3
y = np.zeros(len(t))             # Array mit gleicher Groesse
for i in xrange(len(t)):
    y[i] = f(t[i])            # Funktionswerte berechnen

plt.plot(t, y)
show()
